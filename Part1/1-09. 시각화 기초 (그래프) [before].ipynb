# %% [markdown]
# # Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
data = np.random.randn(50).cumsum()
data
# Out:
# array([ 2.99829361,  1.93463333,  2.68809849,  3.19713751,  5.00420867,
#         5.45887046,  5.84939429,  7.3607257 ,  6.81354288,  5.28926282,
#         4.67140841,  5.38515861,  5.01014888,  4.15550575,  2.19497395,
#         3.08603931,  3.06590728,  1.94084428,  2.86050434,  2.30592068,
#         2.36359227,  2.00000945,  2.8617915 ,  2.3900421 ,  1.57294841,
#         1.65475397,  1.27727805,  2.77680602,  2.95213269,  2.75433508,
#         2.55726448,  3.18235533,  3.05432164,  3.066628  ,  0.7928007 ,
#         1.15961766, -0.61499301, -1.23005251, -2.42948393, -0.67716083,
#        -0.87416536, -1.26394106, -1.54792639, -1.90369542, -0.58466278,
#        -0.1021646 , -1.40067005, -1.0580532 , -1.51933045, -1.78406147])

# %%
plt.plot(data)
plt.show()

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(1, 2, 1) # 행의 개수 , 열의 개수  , 첫번째것을 그리겠다 # matplotlib은 1이 시작이다
plt.subplot(1, 2, 2)
plt.show()

# %%
plt.subplot(3, 2, 1)
plt.subplot(3, 2, 2)
plt.subplot(3, 2, 3)
plt.subplot(3, 2, 4)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Multi Graph 그리기

# %%
plt.plot(data)

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(30)

# %%
plt.subplot(2,2,1)
plt.plot(data)

plt.subplot(2,2,2)
plt.hist(hist_data, bins = 20)

plt.subplot(2,2,3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))
plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
plt.plot(data)
plt.show()

# %%
plt.plot(data, 'g')
plt.show()

# %%
plt.plot(data, 'y')
plt.show()

# %%
plt.plot(data, 'y.')
plt.show()

# %%
plt.plot(data, 'y--')
plt.show()

# %%
plt.plot(data, 'y^')
plt.show()

# %%
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.plot(data, 'k+')
plt.show()

# %%
plt.figure(figsize=(10,10)) # 단위가 인치이다
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize = (5, 5))

plt.subplot(2,2,1)
plt.plot(data)

plt.subplot(2,2,2)
plt.hist(hist_data, bins = 20)

plt.subplot(2,2,3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))

plt.show()

# %%
plt.figure(figsize = (10, 10))

plt.subplot(2,2,1)
plt.plot(data)

plt.subplot(2,2,2)
plt.hist(hist_data, bins = 20)

plt.subplot(2,2,3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))

plt.show()

# %% [markdown]
# - 비율 조절

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--')
plt.plot(data, 'k-', drawstyle = 'steps-post')
plt.show()

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label = "Default")
plt.plot(data, 'k-', drawstyle = 'steps-post', label = 'steps-post')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 이름 달기

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Random Graph')
plt.show()

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Random Graph')
plt.xlabel('Stages')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ---
# ## 종합

# %%
plt.plot(np.random.randn(1000).cumsum(), 'k^', label='one')
plt.plot(np.random.randn(1000).cumsum(), 'y.', label='two')
plt.plot(np.random.randn(1000).cumsum(), 'r*', label='three')
plt.title('Graph')
plt.xlabel('good')
plt.ylabel('score')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 그래프 저장하기

# %%
plt.savefig('saved_graph.svg')
